# %%
import pandas as pd
df_ocorrencia = pd.read_csv("../data/ocorrencia.csv", sep=';', encoding='latin-1')
df_aeronave = pd.read_csv('../data/aeronave.csv', sep=';', encoding='latin-1')

print(df_ocorrencia)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0                 83097               83097               83097
# 1                 83085               83085               83085
# 2                 83074               83074               83074
# 3                 83063               83063               83063
# 4                 83051               83051               83051
# ...                 ...                 ...                 ...
# 9816              28377               28377               28377
# 9817              28375               28375               28375
# 9818              28355               28355               28355
# 9819              28335               28335               28335
# 9820              28256               28256               28256
#
#       codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0                  83097               83097                 ACIDENTE
# ...
